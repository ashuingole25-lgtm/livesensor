# %%
pip install pymongo
# Out:
# Requirement already satisfied: pymongo in e:\data_science\sensorlive\venv\lib\site-packages (4.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymongo
from pymongo import MongoClient

# %%
connection_string = "mongodb+srv://Ashwini:Ashwini25@cluster0.yymak3q.mongodb.net/?appName=Cluster0"

# %%
client = MongoClient(connection_string)

# %%
db = client["Liveclass"]

# %%
collection = db["mongoclass"]

# %%
data = {"name": "Ashwini",
        "age": 32,
        "email": "ashu.ingole25@gmail.com"}

# %%
collection.insert_one(data)

# %%
cursor = collection.find({})
for i in cursor:
    print(i)
# Out:
# {'_id': ObjectId('6909f4280935cf53dc348378'), 'name': 'Ashwini'}
# {'_id': ObjectId('6909f5000935cf53dc348379'), 'name': 'Ashwini', 'age': 32, 'email': 'ashu.ingole25@gmail.com'}
